# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Luay Matalka
# * Student pace: full time
# * Scheduled project review date/time: 6/1/1:15 PM CST
# * Instructor name: Amber Yandow
# * Blog post URL: https://luaymatalka.github.io/

# %% [markdown]
# ## Module 3 Project: Tanzania Water Well Data
#
# __Hand-driven and gravity fed water pumps are a key source of potable water throughout much of Africa and Asia, and the ongoing management and maintenance of such pumps is an ever-present challenge for many communities.__
#
# __Using data from Taarifa and the Tanzanian Ministry of Water, we want to predict which pumps are functional, which need some
# repairs, and which don't work at all.We have to predict based on a number of variables about what kind of pump is operating,
# when it was installed, and how it is managed. A smart understanding of which waterpoints will fail and we can improve
# maintenance operations and ensure that clean, potable water is available to communities across Tanzania.__
#
# __According to Tanzania’s Ministry of Water, more than 74,000 such pumps can be found throughout the country. While the installation of these pumps is largely funded via contributions from charitable and other non-governmental organizations (NGO’s), their ongoing maintenance is typically the responsibility of the local community within which they reside. Unfortunately, the cost of maintaining the pumps is often beyond the means of the local community, resulting in pumps becoming non-functional. Furthermore, local communities are often unaware of the need to perform the required maintenance due to the apparent lack of any significant problems with a pump up until the point it ultimately fails.__

# %% [markdown]
# ### Questions to answer:
#
# 1) Does the source of water affect the likelihood for needing repairs?
#
# 2) Does the region affect the likelihood for needing repairs?
#
# 3) Do public meetings regarding the state of a pump affect its outcome in regards to needing repairs?
#
# 4) What are some other factors that influence the need for repairs?

# %% [markdown]
# ## Methodology:
#
# __Research__ - Find out about various models and see which model wroks best for our data.
# __Obtain__ - This step involves understanding stakeholder requirements, gathering information on the problem, and finally,
# sourcing data that we think will be necessary for solving this problem.
# __Scrub__- During this stage, we'll focus on preprocessing our data. Important steps such as identifying and removing null
# values, dealing with outliers, normalizing data, and feature engineering/feature selection are handled around this stage.
# __Explore__ - During this step, you'll create visualizations to really get a feel for your dataset. You'll focus on things such
# as understanding the distribution of different columns, checking for multicollinearity, and other tasks like that.
# __Model__ - It consists of building and tuning models using all the tools you have in your data science toolbox. In practice,
# this often means defining a threshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results.
# __Evaluate__ - During this step, you'll interpret the results of your model(s), and communicate results to stakeholders. If
# your results are satisfactory to all stakeholders involved, you may also go from this stage right into putting your model
# into production and automating processes necessary to support it.
# __Deploy__ - Deploying the Model.

# %% [markdown]
# ### Research:
#
# __Models to try:__
#
# - __LinearSVC__
# -  __XGBoost__
# -  __Random Forest__

# %% [markdown]
# __Linear SVC__ - Linear Support Vector Classifier
# The objective of a Linear SVC (Support Vector Classifier) is to fit to the data you provide, returning a "best fit"
# hyperplane that divides, or categorizes, your data. From there, after getting the hyperplane, you can then feed some
# features to your classifier to see what the "predicted" class is. This makes this specific algorithm rather suitable for our
# uses, though you can use this for many situations.
# - __penalty{‘l1’, ‘l2’}__ : default=’l2’.Specifies the norm used in the penalization. The ‘l2’ penalty is the standard used in
# SVC. The ‘l1’ leads to coef_ vectors that are sparse.__
# - __loss{‘hinge’, ‘squared_hinge’}__ : default=’squared_hinge’. Specifies the loss function. ‘hinge’ is the standard SVM loss
# (used e.g. by the SVC class) while ‘squared_hinge’ is the square of the hinge loss.
# - __multi_class{‘ovr’, ‘crammer_singer’}__ : default=’ovr’.Determines the multi-class strategy if y contains more than two
# classes. "ovr" trains n_classes one-vs-rest classifiers, while "crammer_singer" optimizes a joint objective over all classes.
# While crammer_singer is interesting from a theoretical perspective as it is consistent, it is seldom used in practice as it
# rarely leads to better accuracy and is more expensive to compute. If "crammer_singer" is chosen, the options loss, penalty
# and dual will be ignored.

# %% [markdown]
# __Random Forest, Decision Trees__
#
# - __n_estimators (random forest only)__: number of decision trees used in making the forest (default = 100). Generally
# speaking, the more uncorrelated trees in our forest, the closer their individual errors get to averaging out. However,
# more does not mean better since this can have an exponential effect on computation costs. After a certain point, there
# exists statistical evidence of diminishing returns. Bias-Variance Tradeoff: in theory, the more trees, the more overfit the
# model (low bias). However, when coupled with bagging, we need not worry'
# - __max_depth__: 'an integer that sets the maximum depth of the tree. The default is None, which means the nodes are expanded
# until all the leaves are pure (i.e., all the data belongs to a single class) or until all leaves contain less than the
# min_samples_split, which we will define next. Bias-Variance Tradeoff: increasing the max_depth leads to overfitting (low
# bias)'
# - __min_samples_split__: 'is the minimum number of samples required to split an internal node. Bias-Variance Tradeoff: the
# higher the minimum, the more “clustered” the decision will be, which could lead to underfitting (high bias)'
# - __min_samples_leaf__: 'defines the minimum number of samples needed at each leaf. The default input here is 1. Bias-Variance
# Tradeoff: similar to min_samples_split, if you do not allow the model to split (say because your min_samples_lear parameter
# is set too high) your model could be over generalizing the training data (high bias)'
# - __criterion__: 'measures the quality of the split and receives either “gini”, for Gini impurity (default), or “entropy”, for
# information gain. Gini impurity is the probability of incorrectly classifying a randomly chosen datapoint if it were labeled according to the class distribution of the dataset. Entropy is a measure of chaos in your data set. If a split in the dataset results in lower entropy, then you have gained information (i.e., your data has become more decision useful) and the split is worthy of the additional computational costs'

# %% [markdown]
# __XG Boost__
#
# - __n_estimators__: is the maximum number of estimators at which boosting is terminated. If a perfect fit is reached, the
# algo is stopped. The default here is 50. Bias-Variance Tradeoff: the higher the number of estimators in your model the lower
# the bias.
# - __learning_rate__: is the rate at which we are adjusting the weights of our model with respect to the loss gradient. In
# layman’s terms: the lower the learning_rate, the slower we travel along the slope of the loss function.
# Important note: there is a trade-off between learning_rate and n_estimators as a tiny learning_rate and a large n_estimators
# will not necessarily improve results relative to the large computational costs.
# - __base_estimator__ (AdaBoost) / Loss (Gradient Boosting): is the base estimator from which the boosted ensemble is built.
# For AdaBoost the default value is None, which equates to a Decision Tree Classifier with max depth of 1 (a stump). For
# Gradient Boosting the default value is deviance, which equates to Logistic Regression. If “exponential” is passed, the
# AdaBoost algorithm is used.

# %%
# importing the libraries

import pandas as pd
import numpy as np

from scipy import stats
import math

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn')

import contextily as ctx
import geopandas

# sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score
from sklearn.impute import SimpleImputer

import itertools

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Obtain the data

# %%
# Import the data as dataframes

df_train = pd.read_csv('zippedData/trainingData.csv')
df_test = pd.read_csv('zippedData/testData.csv')
df_labels = pd.read_csv('zippedData/labels.csv')

# %% [markdown]
# ### Scrub the data

# %%
# Concatenate df_train and df_test, then join them with df_labels into a new dataframe

original_df = pd.concat([df_train, df_test]).set_index('id').join(df_labels.set_index('id')).reset_index()

# %%
# Check the total_df top 5 rows

original_df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0     3/14/2011         Roman        1390         Roman
# 1   8776         0.0      3/6/2013       Grumeti        1399       GRUMETI
# 2  34310        25.0     2/25/2013  Lottery Club         686  World vision
# 3  67743         0.0     1/28/2013        Unicef         263        UNICEF
# 4  19728         0.0     7/13/2011   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
# ...

# %%
# Check the shape of the df

original_df.shape
# Out:
# (74250, 41)

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74250 entries, 0 to 74249
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     74250 non-null  int64
#  1   amount_tsh             74250 non-null  float64
#  2   date_recorded          74250 non-null  object
#  3   funder                 69746 non-null  object
#  4   gps_height             74250 non-null  int64
#  5   installer              69718 non-null  object
#  6   longitude              74250 non-null  float64
#  7   latitude               74250 non-null  float64
#  8   wpt_name               74250 non-null  object
#  9   num_private            74250 non-null  int64
#  10  basin                  74250 non-null  object
#  11  subvillage             73780 non-null  object
#  12  region                 74250 non-null  object
#  13  region_code            74250 non-null  int64
# ...

# %%
original_df = original_df.dropna(subset=['status_group'])

# %%
original_df = original_df.drop_duplicates()

# %%
original_df.shape
# Out:
# (59400, 41)

# %% [markdown]
# ### Feature Descriptions:
#
# - amount_tsh - Total static head (amount water available to waterpoint)
# - date_recorded - The date the row was entered
# - funder - Who funded the well
# - gps_height - Altitude of the well
# - installer - Organization that installed the well
# - longitude - GPS coordinate
# - latitude - GPS coordinate
# - wpt_name - Name of the waterpoint if there is one
# - num_private -
# - basin - Geographic water basin
# - subvillage - Geographic location
# - region - Geographic location
# - region_code - Geographic location (coded)
# - district_code - Geographic location (coded)
# - lga - Geographic location
# - ward - Geographic location
# - population - Population around the well
# - public_meeting - True/False
# - recorded_by - Group entering this row of data
# - scheme_management - Who operates the waterpoint
# - scheme_name - Who operates the waterpoint
# - permit - If the waterpoint is permitted
# - construction_year - Year the waterpoint was constructed
# - extraction_type - The kind of extraction the waterpoint uses
# - extraction_type_group - The kind of extraction the waterpoint uses
# - extraction_type_class - The kind of extraction the waterpoint uses
# - management - How the waterpoint is managed
# - management_group - How the waterpoint is managed
# - payment - What the water costs
# - payment_type - What the water costs
# - water_quality - The quality of the water
# - quality_group - The quality of the water
# - quantity - The quantity of water
# - quantity_group - The quantity of water
# - source - The source of the water
# - source_type - The source of the water
# - source_class - The source of the water
# - waterpoint_type - The kind of waterpoint
# - waterpoint_type_group - The kind of waterpoint

# %%
original_df.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group', 'status_group'],
#       dtype='object')

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
original_df.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# ...

# %%
original_df['status_group'].value_counts()
# Out:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64

# %%
# make a copy of original_df

df = original_df.copy()

# %%
# Replace functional with 0, and non-functional and functional needs repair with 1 (positive class)

df['target'] = df['status_group'].replace({'functional': 0, 'non functional': 1, 'functional needs repair': 1})

# %%
# replace functional needs repairs and non functional with needs repairs

df['status_group'] = df['status_group'].replace({'non functional': 'needs repairs', 'functional needs repair': 'needs repairs'})

# %%
df['status_group'].value_counts()
# Out:
# functional       32259
# needs repairs    27141
# Name: status_group, dtype: int64

# %%
df['target'].value_counts(normalize=True)
# Out:
# 0    0.543081
# 1    0.456919
# Name: target, dtype: float64

# %%
df.isna().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
# Check that the new target column was added

df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0     3/14/2011         Roman        1390         Roman
# 1   8776         0.0      3/6/2013       Grumeti        1399       GRUMETI
# 2  34310        25.0     2/25/2013  Lottery Club         686  World vision
# 3  67743         0.0     1/28/2013        Unicef         263        UNICEF
# 4  19728         0.0     7/13/2011   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... quality_group  \
# 0  34.938093  -9.856322                  none            0  ...          good
# 1  34.698766  -2.147466              Zahanati            0  ...          good
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          good
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          good
# 4  31.130847  -1.825359               Shuleni            0  ...          good
#
# ...

# %%
# 54% of wells are functional and don't need repairs, 45% of wells need repairs 

df['target'].value_counts(normalize=True)
# Out:
# 0    0.543081
# 1    0.456919
# Name: target, dtype: float64

# %% [markdown]
# ### Administrative Features:
# - Used by/for the company performing the survey and thus can be removed.
#     - __id__ - unique id numer for each individual waterwell
#     - __date_recorded__ - date wich the survey company entered the data into the dataset
#     - __recorded_by__ - name of the company responsible for surveying and recording the waterwell statistics. GeoData Consultants Ltd for all observations.

# %% [markdown]
# ### Categorical Features:

# %%
# funder - the organization that paid for the construction of the well

print(f"Unique Values: {df['funder'].nunique()}")
print(f"Missing Values: {df['funder'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['funder'] == '0').sum()} (wells with '0' as the value)")
df['funder'].value_counts().head(20)
# Out:
# Unique Values: 1897
# Missing Values: 3635/59400
# Possible Missing Values: 777 (wells with '0' as the value)
# Government Of Tanzania    9084
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
# World Bank                1349
# Kkkt                      1287
# World Vision              1246
# Unicef                    1057
# Tasaf                      877
# District Council           843
# Dhv                        829
# Private Individual         826
# Dwsp                       811
# 0                          777
# Norad                      765
# Germany Republi            610
# Tcrs                       602
# Ministry Of Water          590
# Water                      583
# Dwe                        484
# Name: funder, dtype: int64

# %%
# water_quality

print(f"Unique Values: {df['water_quality'].nunique()}")
print(f"Missing Values: {df['water_quality'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['water_quality'] == '0').sum()} (wells with '0' as the value)")
df['water_quality'].value_counts().head(20)
# Out:
# Unique Values: 8
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64

# %%
# Functionality Based on Quality of Water

source_df = df.groupby('water_quality')['status_group'].value_counts(ascending=True).unstack()
source_df.plot(kind='bar', color=['brown','midnightblue'], figsize=(10,5))
plt.xlabel("Quality of Water")
plt.xticks(rotation=90)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Quality of Water', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
# Likelihood of Needing Repairs vs. Quality of Water

source_df = df.groupby('water_quality')['target'].mean()
source_df.sort_values().plot(kind='bar', color = ['brown'], figsize=(10,5))
plt.xlabel("Quality of Water")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Quality of Water', fontsize=14, fontweight='bold');

# %%
# installer - the one that installed the well

print(f"Unique Values: {df['installer'].nunique()}")
print(f"Missing Values: {df['installer'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['installer'] == '0').sum()} (wells with '0' as the value)")
df['installer'].value_counts().head(20)
# Out:
# Unique Values: 2145
# Missing Values: 3655/59400
# Possible Missing Values: 777 (wells with '0' as the value)
# DWE                   17402
# Government             1825
# RWE                    1206
# Commu                  1060
# DANIDA                 1050
# KKKT                    898
# Hesawa                  840
# 0                       777
# TCRS                    707
# Central government      622
# CES                     610
# Community               553
# DANID                   552
# District Council        551
# HESAWA                  539
# LGA                     408
# World vision            408
# WEDECO                  397
# TASAF                   396
# District council        392
# Name: installer, dtype: int64

# %% [markdown]
# __DWE: District Water Engineering__
# We see that DWE and Govt are the major installers which is similar to our funders.

# %%
# wpt_name

print(f"Unique Values: {df['wpt_name'].nunique()}")
print(f"Missing Values: {df['wpt_name'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['wpt_name'] == '0').sum()} (wells with '0' as the value)")
df['wpt_name'].value_counts().head(20)
# Out:
# Unique Values: 37400
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# none               3563
# Shuleni            1748
# Zahanati            830
# Msikitini           535
# Kanisani            323
# Bombani             271
# Sokoni              260
# Ofisini             254
# School              208
# Shule Ya Msingi     199
# Shule               152
# Sekondari           146
# Muungano            133
# Mkombozi            111
# Madukani            104
# Mbugani              94
# Hospital             94
# Upendo               93
# Kituo Cha Afya       90
# Mkuyuni              88
# Name: wpt_name, dtype: int64

# %% [markdown]
# We see that there are lot of unique values here. Some belong to a school, mosque or even to a name of a person. Hence, we will not be considering this feature for our modeling.

# %% [markdown]
# __Geographical Features__
#
# Tanzania is divided into thirty-one regions (mkoa in Swahili). Each region is subdivided into districts (wilaya in Swahili). The districts are sub-divided into divisions (tarafa in Swahili) and further into local wards (kata in Swahili). Wards are further subdivided for management purposes: for urban wards into streets (mtaa in Swahili) and for rural wards into villages (kijiji in Swahili). The villages may be further subdivided into hamlets (vitongoji in Swahili).

# %%
print(f"Basins: {df['basin'].nunique()}")
print(f"Region: {df['region'].nunique()}")
print(f"Districts: {df['district_code'].nunique()}")
print(f"LGAs: {df['lga'].nunique()}")
print(f"Wards: {df['ward'].nunique()}")
print(f"Subvillages: {df['subvillage'].nunique()}")
# Out:
# Basins: 9
# Region: 21
# Districts: 20
# LGAs: 125
# Wards: 2092
# Subvillages: 19287

# %%
# basin - Name of geographic water basin where pump is located

print(f"Unique Values: {df['basin'].nunique()}")
print(f"Missing Values: {df['basin'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['basin'] == '0').sum()} (wells with '0' as the value)")
df['basin'].value_counts().head(20)
# Out:
# Unique Values: 9
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64

# %%
df['basin'].value_counts(ascending=False).plot.bar(figsize=(6, 4), rot=90)
plt.title('Basin', fontsize=14);

# %%
# Pump Functionality Based on Basin (Water Source)

sub_df = df.groupby('basin')['status_group'].value_counts(ascending=True).unstack()
sub_df.plot(kind='bar', color=['brown','midnightblue'], figsize=(8,5))
plt.xlabel("Water Source (Basin)", fontweight='bold')
plt.xticks(rotation=45,fontweight='bold')
plt.ylabel("Value Counts")
plt.title('Pump Functionality Based on Basin (Water Source)', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 0.9), title='Status');

# %%
source_df = df.groupby('basin')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Quality of Water")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Basin (Water Source)', fontsize=14, fontweight='bold');

# %%
# district code

print(f"Unique Values: {df['district_code'].nunique()}")
print(f"Missing Values: {df['district_code'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['district_code'] == '0').sum()} (wells with '0' as the value)")
df['district_code'].value_counts().head(20)
# Out:
# Unique Values: 20
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
# region

print(f"Unique Values: {df['region'].nunique()}")
print(f"Missing Values: {df['region'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['region'] == '0').sum()} (wells with '0' as the value)")
df['region'].value_counts().head(20)
# Out:
# Unique Values: 21
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# Iringa         5294
# Shinyanga      4982
# Mbeya          4639
# Kilimanjaro    4379
# Morogoro       4006
# Arusha         3350
# Kagera         3316
# Mwanza         3102
# Kigoma         2816
# Ruvuma         2640
# Pwani          2635
# Tanga          2547
# Dodoma         2201
# Singida        2093
# Mara           1969
# Tabora         1959
# Rukwa          1808
# Mtwara         1730
# Manyara        1583
# Lindi          1546
# Name: region, dtype: int64

# %%
# Pump Functionality Based on Region

sub_df = df.groupby('region')['status_group'].value_counts(ascending=True).unstack()
sub_df.plot(kind='bar', figsize=(10,5))
plt.xlabel("Region")
plt.xticks(rotation=45,fontweight='bold')
plt.ylabel("Pump Functionality Counts")
plt.title('Pump Functionality Based on Region', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 0.9), title='Status');

# %%
source_df = df.groupby('region')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Region")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Region', fontsize=14, fontweight='bold');

# %%
# region_code

print(f"Unique Values: {df['region_code'].nunique()}")
print(f"Missing Values: {df['region_code'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['region_code'] == '0').sum()} (wells with '0' as the value)")
df['region_code'].value_counts().head(20)
# Out:
# Unique Values: 27
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# Name: region_code, dtype: int64

# %%
# lga - Tanzania-specific geographic indicator of where pump is located

print(f"Unique Values: {df['lga'].nunique()}")
print(f"Missing Values: {df['lga'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['lga'] == '0').sum()} (wells with '0' as the value)")
df['lga'].value_counts().head(20)
# Out:
# Unique Values: 125
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# Njombe           2503
# Arusha Rural     1252
# Moshi Rural      1251
# Bariadi          1177
# Rungwe           1106
# Kilosa           1094
# Kasulu           1047
# Mbozi            1034
# Meru             1009
# Bagamoyo          997
# Singida Rural     995
# Kilombero         959
# Same              877
# Kibondo           874
# Kyela             859
# Kahama            836
# Magu              824
# Kigoma Rural      824
# Maswa             809
# Karagwe           771
# Name: lga, dtype: int64

# %%
# subvillage - the smallest of the geographic subdivisions, right underneath 'ward' in terms of hierchy

print(f"Unique Values: {df['subvillage'].nunique()}")
print(f"Missing Values: {df['subvillage'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['subvillage'] == '0').sum()} (wells with '0' as the value)")
df['subvillage'].value_counts().head(20)
# Out:
# Unique Values: 19287
# Missing Values: 371/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# Madukani      508
# Shuleni       506
# Majengo       502
# Kati          373
# Mtakuja       262
# Sokoni        232
# M             187
# Muungano      172
# Mbuyuni       164
# Mlimani       152
# Songambele    147
# Miembeni      134
# Msikitini     134
# 1             132
# Kibaoni       114
# Kanisani      111
# Mapinduzi     109
# I             109
# Mjini         108
# Mjimwema      108
# Name: subvillage, dtype: int64

# %%
# ward - The 'ward' category is the smallest of the geographic features

print(f"Unique Values: {df['ward'].nunique()}")
print(f"Missing Values: {df['ward'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['ward'] == '0').sum()} (wells with '0' as the value)")
df['ward'].value_counts().head(20)
# Out:
# Unique Values: 2092
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# Igosi            307
# Imalinyi         252
# Siha Kati        232
# Mdandu           231
# Nduruma          217
# Kitunda          203
# Mishamo          203
# Msindo           201
# Chalinze         196
# Maji ya Chai     190
# Usuka            187
# Ngarenanyuki     172
# Chanika          171
# Vikindu          162
# Mtwango          153
# Matola           145
# Zinga/Ikerege    141
# Maramba          139
# Wanging'ombe     139
# Itete            137
# Name: ward, dtype: int64

# %%
# public_meeting

print(f"Unique Values: {df['public_meeting'].nunique()}")
print(f"Missing Values: {df['public_meeting'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['public_meeting'] == '0').sum()} (wells with '0' as the value)")
df['public_meeting'].value_counts().head(20)
# Out:
# Unique Values: 2
# Missing Values: 3334/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# True     51011
# False     5055
# Name: public_meeting, dtype: int64

# %%
# Pump Functionality Based on Public Meetings

sub_df = df.groupby('public_meeting')['status_group'].value_counts(ascending=False).unstack()
sub_df.plot(kind='bar', figsize=(5,5))
plt.xlabel("Public Meeting")
plt.xticks(rotation=0,fontweight='bold')
plt.ylabel("Value Counts")
plt.title('Pump Functionality Based on Public Meetings', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('public_meeting')['target'].mean()
source_df.plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Public Meeting")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Public Meeting', fontsize=14, fontweight='bold');

# %%
# scheme_management

print(f"Unique Values: {df['scheme_management'].nunique()}")
print(f"Missing Values: {df['scheme_management'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['scheme_management'] == '0').sum()} (wells with '0' as the value)")
df['scheme_management'].value_counts().head(20)
# Out:
# Unique Values: 12
# Missing Values: 3877/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# VWC                 36793
# WUG                  5206
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1680
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64

# %%
# Functionality Based on Scheme Management

source_df = df[df['scheme_management'] != 'None'].groupby('scheme_management')['status_group'].value_counts(ascending=False).unstack()
source_df.plot(kind='bar',figsize=(10,5))
plt.xlabel("Scheme Management")
plt.xticks(rotation=45)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Scheme Management', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df[df['scheme_management'] != 'None'].groupby('scheme_management')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Scheme Management")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Scheme Management', fontsize=14, fontweight='bold');

# %%
# scheme_name

print(f"Unique Values: {df['scheme_name'].nunique()}")
print(f"Missing Values: {df['scheme_name'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['scheme_name'] == '0').sum()} (wells with '0' as the value)")
df['scheme_name'].value_counts().head(20)
# Out:
# Unique Values: 2696
# Missing Values: 28166/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# K                                        682
# None                                     644
# Borehole                                 546
# Chalinze wate                            405
# M                                        400
# DANIDA                                   379
# Government                               320
# Ngana water supplied scheme              270
# wanging'ombe water supply s              261
# wanging'ombe supply scheme               234
# I                                        229
# Bagamoyo wate                            229
# Uroki-Bomang'ombe water sup              209
# N                                        204
# Kirua kahe gravity water supply trust    193
# Machumba estate pipe line                185
# Makwale water supplied sche              166
# Kijiji                                   161
# ...

# %%
# permit

print(f"Unique Values: {df['permit'].nunique()}")
print(f"Missing Values: {df['permit'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['permit'] == '0').sum()} (wells with '0' as the value)")
df['permit'].value_counts().head(20)
# Out:
# Unique Values: 2
# Missing Values: 3056/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# True     38852
# False    17492
# Name: permit, dtype: int64

# %%
# Functionality Based on Permit Status

sub_df = df.groupby('permit')['status_group'].value_counts(ascending=True).unstack()
sub_df.plot(kind='bar', figsize=(5,5))
plt.xlabel("Has Permit", fontweight='bold')
plt.xticks(rotation=45,fontweight='bold')
plt.ylabel("Pump Functionality\n")
plt.title('Functionality Based on Permit Status', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.2, 1.0), title='Status');

# %%
source_df = df.groupby('permit')['target'].mean()
source_df.plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Has Permit")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Has Permit', fontsize=14, fontweight='bold');

# %%
print(f"Unique Values: {df['extraction_type'].nunique()}")
print(f"Missing Values: {df['extraction_type'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['extraction_type'] == '0').sum()} (wells with '0' as the value)")
df['extraction_type'].value_counts().head(20)
# Out:
# Unique Values: 18
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# gravity                      26780
# nira/tanira                   8154
# other                         6430
# submersible                   4764
# swn 80                        3670
# mono                          2865
# india mark ii                 2400
# afridev                       1770
# ksb                           1415
# other - rope pump              451
# other - swn 81                 229
# windmill                       117
# india mark iii                  98
# cemo                            90
# other - play pump               85
# walimi                          48
# climax                          32
# other - mkulima/shinyanga        2
# Name: extraction_type, dtype: int64

# %%
# extraction_type_group: kind of extraction the waterpoint uses

print(f"Unique Values: {df['extraction_type_group'].nunique()}")
print(f"Missing Values: {df['extraction_type_group'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['extraction_type_group'] == '0').sum()} (wells with '0' as the value)")
df['extraction_type_group'].value_counts().head(20)
# Out:
# Unique Values: 13
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# gravity            26780
# nira/tanira         8154
# other               6430
# submersible         6179
# swn 80              3670
# mono                2865
# india mark ii       2400
# afridev             1770
# rope pump            451
# other handpump       364
# other motorpump      122
# wind-powered         117
# india mark iii        98
# Name: extraction_type_group, dtype: int64

# %%
# extraction_type_class

print(f"Unique Values: {df['extraction_type_class'].nunique()}")
print(f"Missing Values: {df['extraction_type_class'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['extraction_type_class'] == '0').sum()} (wells with '0' as the value)")
df['extraction_type_class'].value_counts().head(20)
# Out:
# Unique Values: 7
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# gravity         26780
# handpump        16456
# other            6430
# submersible      6179
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64

# %%
# Functionality Based on Extraction Type Class

source_df1 = df.groupby('extraction_type_group')['status_group'].value_counts(ascending=True).unstack()
source_df1.plot(kind='bar', color=['green','blue'], figsize=(10,5))
plt.xlabel("Extraction Type Group")
plt.xticks(rotation=45)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Extraction Type Group', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('extraction_type_group')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Extraction Type Class")
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Extraction Type Group', fontsize=14, fontweight='bold');

# %% [markdown]
# extraction type, extraction_type_group and extraction_type are all similar. Will only use extraction_type_group for modeling.

# %%
# payment

print(f"Unique Values: {df['payment'].nunique()}")
print(f"Missing Values: {df['payment'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['payment'] == '0').sum()} (wells with '0' as the value)")
df['payment'].value_counts().head(20)
# Out:
# Unique Values: 7
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# never pay                25348
# pay per bucket            8985
# pay monthly               8300
# unknown                   8157
# pay when scheme fails     3914
# pay annually              3642
# other                     1054
# Name: payment, dtype: int64

# %%
# payment_type - similar to payment

print(f"Unique Values: {df['payment_type'].nunique()}")
print(f"Missing Values: {df['payment_type'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['payment_type'] == '0').sum()} (wells with '0' as the value)")
df['payment_type'].value_counts().head(20)
# Out:
# Unique Values: 7
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64

# %%
# Functionality Based on Payment Type

source_df1 = df.groupby('payment_type')['status_group'].value_counts(ascending=True).unstack()
source_df1.plot(kind='bar', color=['orange','grey'], figsize=(10,5))
plt.xlabel("Payment Type")
plt.xticks(rotation=90)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Payment Type', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('payment_type')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Payment Type")
plt.xticks(rotation=90)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Payment Type', fontsize=14, fontweight='bold');

# %%
# quality_group

print(f"Unique Values: {df['quality_group'].nunique()}")
print(f"Missing Values: {df['quality_group'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['quality_group'] == '0').sum()} (wells with '0' as the value)")
df['quality_group'].value_counts().head(20)
# Out:
# Unique Values: 6
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64

# %%
# quantity_group

print(f"Unique Values: {df['quantity_group'].nunique()}")
print(f"Missing Values: {df['quantity_group'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['quantity_group'] == '0').sum()} (wells with '0' as the value)")
df['quantity_group'].value_counts().head(20)
# Out:
# Unique Values: 5
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity_group, dtype: int64

# %%
# quantity

print(f"Unique Values: {df['quantity'].nunique()}")
print(f"Missing Values: {df['quantity'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['quantity'] == '0').sum()} (wells with '0' as the value)")
df['quantity'].value_counts().head(20)
# Out:
# Unique Values: 5
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64

# %%
# Water Pump Functionality based on Water Quantity

qty_df = df.groupby('quantity')['status_group'].value_counts(ascending=True).unstack()
qty_df.plot(kind='bar', color=['midnightblue','firebrick'], figsize=(10,5))
plt.xlabel("Water Quantity")
plt.xticks(rotation=0)
plt.ylabel("Pump Functionality Count")
plt.title('Water Pump Functionality based on Water Quantity', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('quantity')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel("Quantity of Water")
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Water Quantity', fontsize=14, fontweight='bold');

# %%
# source

print(f"Unique Values: {df['source'].nunique()}")
print(f"Missing Values: {df['source'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['source'] == '0').sum()} (wells with '0' as the value)")
df['source'].value_counts().head(20)
# Out:
# Unique Values: 10
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# spring                  17021
# shallow well            16824
# machine dbh             11075
# river                    9612
# rainwater harvesting     2295
# hand dtw                  874
# lake                      765
# dam                       656
# other                     212
# unknown                    66
# Name: source, dtype: int64

# %%
# source_type

print(f"Unique Values: {df['source_type'].nunique()}")
print(f"Missing Values: {df['source_type'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['source_type'] == '0').sum()} (wells with '0' as the value)")
df['source_type'].value_counts().head(20)
# Out:
# Unique Values: 7
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# spring                  17021
# shallow well            16824
# borehole                11949
# river/lake              10377
# rainwater harvesting     2295
# dam                       656
# other                     278
# Name: source_type, dtype: int64

# %%
# Functionality Based on Water Source

source_df = df.groupby('source')['status_group'].value_counts(ascending=False).unstack()
source_df.plot(kind='bar', figsize=(10,5))
plt.xlabel("Water Source")
plt.xticks(rotation=45)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Water Source', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('source')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel('Water Source')
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Water Source', fontsize=14, fontweight='bold');

# %%
# source_class

print(f"Unique Values: {df['source_class'].nunique()}")
print(f"Missing Values: {df['source_class'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['source_class'] == '0').sum()} (wells with '0' as the value)")
df['source_class'].value_counts().head(20)
# Out:
# Unique Values: 3
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# groundwater    45794
# surface        13328
# unknown          278
# Name: source_class, dtype: int64

# %%
# Functionality Based on Source of Water

payment_df = df.groupby('source_class')['status_group'].value_counts(ascending=True).unstack()
payment_df.plot(kind='bar',  color=['darkgreen','midnightblue'], figsize=(10,5))
plt.xlabel("Source of Water")
plt.ylabel("Value Count")
plt.title('Functionality Based on Source of Water', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('source_class')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel('Water Source')
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Water Source', fontsize=14, fontweight='bold');

# %% [markdown]
# Most wells have groundwater as their water source.

# %%
# waterpoint_type

print(f"Unique Values: {df['waterpoint_type'].nunique()}")
print(f"Missing Values: {df['waterpoint_type'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['waterpoint_type'] == '0').sum()} (wells with '0' as the value)")
df['waterpoint_type'].value_counts().head(20)
# Out:
# Unique Values: 7
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# communal standpipe             28522
# hand pump                      17488
# other                           6380
# communal standpipe multiple     6103
# improved spring                  784
# cattle trough                    116
# dam                                7
# Name: waterpoint_type, dtype: int64

# %%
# Functionality Based on Waterpoint Type

source_df = df.groupby('waterpoint_type')['status_group'].value_counts(ascending=False).unstack()
source_df.plot(kind='bar', figsize=(10,5))
plt.xlabel("Waterpoint Type")
plt.xticks(rotation=45)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Waterpoint Type', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df.groupby('waterpoint_type')['target'].mean()
source_df.sort_values().plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel('Waterpoint Type')
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Waterpoint Type', fontsize=14, fontweight='bold');

# %%
# waterpoint_type_group

print(f"Unique Values: {df['waterpoint_type_group'].nunique()}")
print(f"Missing Values: {df['waterpoint_type_group'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['waterpoint_type_group'] == '0').sum()} (wells with '0' as the value)")
df['waterpoint_type_group'].value_counts().head(20)
# Out:
# Unique Values: 6
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# communal standpipe    34625
# hand pump             17488
# other                  6380
# improved spring         784
# cattle trough           116
# dam                       7
# Name: waterpoint_type_group, dtype: int64

# %% [markdown]
# waterpoint_type and waterpoint_type_group are similar hence we will drop waterpoint_type_group.

# %% [markdown]
# ### Numerical Features:

# %%
# gps_height

print(f"Unique Values: {df['gps_height'].nunique()}")
print(f"Missing Values: {df['gps_height'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['gps_height'] == '0').sum()} (wells with '0' as the value)")
df['gps_height'].value_counts().head(20)
# Out:
# Unique Values: 2428
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
#  0       20438
# -15         60
# -16         55
# -13         55
# -20         52
#  1290       52
# -14         51
#  303        51
# -18         49
# -19         47
#  1269       46
#  1295       46
#  1304       45
# -23         45
#  280        44
#  1538       44
#  1286       44
# -8          44
# -17         44
#  1332       43
# Name: gps_height, dtype: int64

# %%
# Status vs. GPS Height

fig, ax = plt.subplots(1)
sns.regplot(x='gps_height', y='target', data=df[(df['gps_height'] != 0)], ax=ax)
ax.set_yticks([0, 1])
plt.title('Well Status and GPS Height', fontsize=14, fontweight='bold');

# %%
sns.boxplot(x='gps_height',y='status_group', data=df, showfliers=False, orient='h')
plt.xlabel("GPS Height")
plt.ylabel('Needs Repairs')
plt.title('Functionality vs. GPS Height', fontsize=16, fontweight='bold');

# %%
# amount_tsh

print(f"Unique Values: {df['amount_tsh'].nunique()}")
print(f"Missing Values: {df['amount_tsh'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['amount_tsh'] == '0').sum()} (wells with '0' as the value)")
df['amount_tsh'].value_counts().head(20)
# Out:
# Unique Values: 98
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 0.0       41639
# 500.0      3102
# 50.0       2472
# 1000.0     1488
# 20.0       1463
# 200.0      1220
# 100.0       816
# 10.0        806
# 30.0        743
# 2000.0      704
# 250.0       569
# 300.0       557
# 5000.0      450
# 5.0         376
# 25.0        356
# 3000.0      334
# 1200.0      267
# 1500.0      197
# 6.0         190
# 600.0       176
# Name: amount_tsh, dtype: int64

# %% [markdown]
# Due to the uneven values, will drop this column.

# %%
# num_private 

print(f"Unique Values: {df['num_private'].nunique()}")
print(f"Missing Values: {df['num_private'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['num_private'] == '0').sum()} (wells with '0' as the value)")
df['num_private'].value_counts().head(20)
# Out:
# Unique Values: 65
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 0      58643
# 6         81
# 1         73
# 5         46
# 8         46
# 32        40
# 45        36
# 15        35
# 39        30
# 93        28
# 3         27
# 7         26
# 2         23
# 65        22
# 47        21
# 102       20
# 4         20
# 17        17
# 80        15
# 20        14
# Name: num_private, dtype: int64

# %% [markdown]
# Since most labels are 0 for this feature, this column will be dropped.

# %%
# population

print(f"Unique Values: {df['population'].nunique()}")
print(f"Missing Values: {df['population'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['population'] == '0').sum()} (wells with '0' as the value)")
df['population'].value_counts().head(20)
      
df['population'].max()
# Out:
# Unique Values: 1049
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 0      21381
# 1       7025
# 200     1940
# 150     1892
# 250     1681
# 300     1476
# 100     1146
# 50      1139
# 500     1009
# 350      986
# 120      916
# 400      775
# 60       706
# 30       626
# 40       552
# 80       533
# 450      499
# 20       462
# 600      438
# 230      388
# Name: population, dtype: int64
# 30500

# %%
def population_num(population):
    return population.map(lambda x: "0" if x < 1 
                                         else ("1-50" if x > 0 and x < 50
                                         else ("50-100" if x >= 50 and x < 100
                                         else ("100-150" if x >= 100 and x < 150
                                         else ("150-200" if x >= 150 and x < 200
                                         else ("200-250" if x >= 200 and x < 250      
                                         else ("250-500" if x >= 250 and x < 500
                                         else ("500-750" if x >= 500 and x < 750
                                         else ("750-1000" if x >= 750 and x < 1000      
                                         else ("1000-1500" if x >= 1000 and x < 1500
                                         else ("1500-2000" if x >= 1500 and x < 2000    
                                         else ("2000-2500" if x >= 2000 and x < 2500
                                         else ("2500-3000" if x >= 2500 and x < 3000  
                                         else ("3000-3500" if x >= 3000 and x < 3500 
                                         else ("3500-4000" if x >= 3500 and x < 4000    
                                         else ("4000-5000" if x >= 4000 and x < 5000
                                         else ("5000-6000" if x >= 5000 and x < 6000
                                         else ("6000-7000" if x >= 6000 and x < 7000    
                                         else ("Above 7000")))))))))))))))))))  
                                    

df['population_bin'] = population_num(df['population']) # applying the function seasons to the dataframe

# %%
df['population_bin'].value_counts()
# Out:
# 0             21381
# 1-50          10250
# 250-500        8193
# 50-100         4521
# 200-250        3335
# 100-150        3269
# 500-750        3011
# 150-200        2814
# 750-1000        936
# 1000-1500       735
# 1500-2000       343
# 2000-2500       216
# 2500-3000       103
# 3000-3500        70
# 4000-5000        58
# 6000-7000        57
# 3500-4000        42
# 5000-6000        40
# Above 7000       26
# Name: population_bin, dtype: int64

# %%
# Functionality Based on Population

source_df = df.groupby('population_bin')['status_group'].value_counts(ascending=False).unstack()
source_df.plot(kind='bar', figsize=(10,5))
plt.xlabel("Population")
plt.xticks(rotation=45)
plt.ylabel("Value Counts")
plt.title('Functionality Based on Population', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.0, 1.0), title='Status');

# %%
source_df = df[df['population_bin'] != '0'].groupby('population_bin')['target'].mean()
source_df.plot(kind='bar', color=['brown'], figsize=(10,5))
plt.xlabel('Population')
plt.xticks(rotation=45)
plt.axhline(y=df['target'].mean(),color='gray') 
plt.ylabel("Likelihood of Needing Repairs")
plt.title('Likelihood of Needing Repairs vs. Population', fontsize=14, fontweight='bold');

# %%
# construction_year

print(f"Unique Values: {df['construction_year'].nunique()}")
print(f"Missing Values: {df['construction_year'].isna().sum()}/{df.shape[0]}")
print(f"Possible Missing Values: {(df['construction_year'] == '0').sum()} (wells with '0' as the value)")
df['construction_year'].value_counts().head(20)
# Out:
# Unique Values: 55
# Missing Values: 0/59400
# Possible Missing Values: 0 (wells with '0' as the value)
# 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# Name: construction_year, dtype: int64

# %%
# will create a new column, Age, which is this year minus the construction year

from datetime import datetime

df['age_of_well']=datetime.now().year - df['construction_year']

# %%
df['age_of_well'].value_counts()
# Out:
# 2020    20709
# 10       2645
# 12       2613
# 11       2533
# 20       2091
# 13       1587
# 14       1471
# 17       1286
# 9        1256
# 16       1123
# 8        1084
# 18       1075
# 42       1037
# 25       1014
# 15       1011
# 21        979
# 22        966
# 30        954
# 35        945
# 40        811
# 24        811
# 36        779
# 38        744
# 26        738
# 48        708
# 46        676
# 23        644
# 28        640
# 27        608
# 19        540
# 32        521
# 37        488
# 45        437
# 34        434
# 44        414
# 50        411
# 29        324
# 31        316
# 33        302
# 39        238
# 43        202
# 41        192
# 47        184
# 7         176
# 49        145
# 60        102
# 53         88
# 57         85
# 52         77
# 51         59
# 56         40
# 58         30
# 59         21
# 55         19
# 54         17
# Name: age_of_well, dtype: int64

# %%
# create a new dataframe that contains positive construction_years, populations, and gps_heights

data = df[(df['construction_year'] > 0) & (df['population'] > 0) & (df['gps_height'] > 0)]
data
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 0      69572      6000.0     3/14/2011                   Roman        1390
# 1       8776         0.0      3/6/2013                 Grumeti        1399
# 2      34310        25.0     2/25/2013            Lottery Club         686
# 3      67743         0.0     1/28/2013                  Unicef         263
# 10     49056         0.0     2/20/2011                 Private          62
# ...      ...         ...           ...                     ...         ...
# 59391  44885         0.0      8/3/2013  Government Of Tanzania         540
# 59394  11164       500.0      3/9/2011              World Bank         351
# 59395  60739        10.0      5/3/2013         Germany Republi        1210
# 59396  27263      4700.0      5/7/2011             Cefa-njombe        1212
# 59399  26348         0.0     3/23/2011              World Bank         191
#
# ...

# %%
# Age of Well vs Functionality

sns.boxplot(y='target',x='age_of_well', data=data, showfliers=False, orient='h')
plt.xlabel("Age of Well")
plt.ylabel('Needs Repairs')
plt.title('Functionality vs. Age of Well', fontsize=16, fontweight='bold');

# %%
df.isna().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
mode_impute = ['installer', 'scheme_management']

# %%
mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
df[mode_impute] = mode_imputer.fit_transform(df[mode_impute])

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28029 entries, 0 to 59396
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     28029 non-null  int64
#  1   amount_tsh             28029 non-null  float64
#  2   date_recorded          28029 non-null  object
#  3   funder                 28029 non-null  object
#  4   gps_height             28029 non-null  int64
#  5   installer              28029 non-null  object
#  6   longitude              28029 non-null  float64
#  7   latitude               28029 non-null  float64
#  8   wpt_name               28029 non-null  object
#  9   num_private            28029 non-null  int64
#  10  basin                  28029 non-null  object
#  11  subvillage             28029 non-null  object
#  12  region                 28029 non-null  object
#  13  region_code            28029 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                       0
# amount_tsh               0
# date_recorded            0
# funder                   0
# gps_height               0
# installer                0
# longitude                0
# latitude                 0
# wpt_name                 0
# num_private              0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# scheme_name              0
# permit                   0
# construction_year        0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# ...

# %% [markdown]
# ### Modeling

# %%
to_drop = ['wpt_name','id','date_recorded','recorded_by','region_code','lga','scheme_name','funder',
           'subvillage','latitude','longitude','extraction_type_class','extraction_type',
           'payment_type','quantity_group','source_type','waterpoint_type_group',
           'amount_tsh','num_private','construction_year','status_group','population'
          ]

# %%
df = df.drop(columns=to_drop)

# %%
X = df.drop(['target'], axis=1)
y = df['target']

# %%
X.shape
# Out:
# (28029, 21)

# %%
y.shape
# Out:
# (28029,)

# %%
numerical_cols = list(X.select_dtypes(include=np.number).columns)
categorical_cols = list(X.select_dtypes(exclude=np.number).columns)

# %%
# Preprocessing for numerical data

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant')),
    ('scale', StandardScaler())
])

# Preprocessing for categorical data

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
import xgboost as xgboost

def fit_predict(model, X_train, X_test, y_train, y_test, smote=False):
    '''fit pipeline using given model, and return predictions'''
    
    param_grid = model['params']
    model = model['model']
        
     # Bundle preprocessing and modeling code in a pipeline
    my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ('model', model)
                                     ])

    search = GridSearchCV(estimator=my_pipeline,
             param_grid=param_grid, n_jobs=-1, verbose=2, cv=10)
    
    search.fit(X_train, y_train)
    
    best_estimator = search.best_estimator_._final_estimator
    
    print("Best parameter (CV score=%0.3f):" % search.best_score_)
    print(search.best_params_)

    # Preprocessing of validation data, get predictions
    test_preds = search.predict(X_test)
    train_preds = search.predict(X_train)
    
    return test_preds, train_preds, search

# %%
def plot_confusion_matrix(y_true, y_preds):
    # Print confusion matrix
    cnf_matrix = confusion_matrix(y_true, y_preds)
    # Create the basic matrix
    plt.imshow(cnf_matrix,  cmap=plt.cm.Blues)
    # Add title and axis labels
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    # Add appropriate axis scales
    class_names = set(y) # Get class labels to add to matrix
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=0)
    plt.yticks(tick_marks, class_names)
    # Add labels to each cell
    thresh = cnf_matrix.max() / 2. # Used for text coloring below
    # Here we iterate through the confusion matrix and append labels to our visualization
    for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
            plt.text(j, i, cnf_matrix[i, j],
                     horizontalalignment='center',
                     color='white' if cnf_matrix[i, j] > thresh else 'black')
    # Add a legend
    plt.colorbar();
    plt.show();

def metrics(model_name, y_train, y_test, y_train_pred, y_test_pred):
    '''Print out the evaluation metrics for a given models predictions'''
    print(f'Model: {model_name}', )
    print('-'*60)
    plot_confusion_matrix(y_test,y_test_pred)
    print(f'test accuracy: {accuracy_score(y_test, y_test_pred)}')
    print(f'train accuracy: {accuracy_score(y_train, y_train_pred)}')
    print('-'*60)
    print('\ntest report:\n' + classification_report(y_test, y_test_pred))
    print('~'*60)
    print('\ntrain report:\n' + classification_report(y_train, y_train_pred))    
    print('-'*60)

# %%
def roc(X_test, y_test, pred_y, model):
    name=str(model.best_estimator_.named_steps["model"])[:str(model.best_estimator_.named_steps["model"]).index('(')]
    y_pred_proba = model.predict_proba(X_test)[:,1]
    fpr, tpr, threshold = roc_curve(y_test, y_pred_proba)
    plt.plot(fpr, tpr, label = model)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC curve for {name}')
    plt.show()

# %% [markdown]
# ### LinearSVC Model

# %%
lsvc_param = {
    'model__C': [1, 10], 
    'model__max_iter': [10000],
    'model__dual':[False],
    'model__penalty': ['l1','l2'],
}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %%
from sklearn.svm import LinearSVC

lsvc = {'model': LinearSVC(random_state=42), 'params': lsvc_param }

lsvc_test_preds, lsvc_train_preds,lsvc_pipeline = fit_predict(lsvc, X_train, X_test, y_train, y_test)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:  3.2min finished
# Best parameter (CV score=0.820):
# {'model__C': 1, 'model__dual': False, 'model__max_iter': 10000, 'model__penalty': 'l1'}

# %%
metrics('LinearSVC', y_train, y_test, lsvc_train_preds, lsvc_test_preds)
# Out:
# Model: LinearSVC
# ------------------------------------------------------------
# test accuracy: 0.8239980972767273
# train accuracy: 0.8543832823649338
# ------------------------------------------------------------
#
# test report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.85      4872
#            1       0.83      0.73      0.78      3537
#
#     accuracy                           0.82      8409
#    macro avg       0.83      0.81      0.82      8409
# weighted avg       0.82      0.82      0.82      8409
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88     11266
#            1       0.87      0.77      0.82      8354
#
#     accuracy                           0.85     19620
#    macro avg       0.86      0.84      0.85     19620
# weighted avg       0.86      0.85      0.85     19620
#
# ...

# %%
import eli5
from sklearn.compose import ColumnTransformer

def top_feat(model_pipe):
    '''This function is used to find the best features of our models
    
    Args:
        model_pipe (GridSearchCV): model_pipe is a pipeline
    
    Returns:
        the top features of the model
    '''
    
    onehot_columns = list(model_pipe.best_estimator_.named_steps['preprocessor'].named_transformers_['cat'].named_steps['onehot'].get_feature_names(input_features=categorical_cols))
    numeric_features_list = list(numerical_cols)
    numeric_features_list.extend(onehot_columns)
    return eli5.explain_weights(model_pipe.best_estimator_.named_steps['model'], top=20, feature_names=numeric_features_list)

# %%
xgb_param = {
    'model__colsample_bytree': [1.0],
    'model__eta': [.3, .2, .1, .05, .01, .005],
    'model__max_depth': [10],
    'model__min_child_weight': [6],
    'model__subsample': [0.8]
}

# %%
from xgboost import XGBClassifier

xgb = { 'model': XGBClassifier(random_state=42), 'params': xgb_param }

xgb_test_preds, xgb_train_preds, xgb_pipeline = fit_predict(xgb, X_train, X_test, y_train, y_test)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.9min finished
# Best parameter (CV score=0.827):
# {'model__colsample_bytree': 1.0, 'model__eta': 0.3, 'model__max_depth': 10, 'model__min_child_weight': 6, 'model__subsample': 0.8}

# %%
metrics('XGBoost', y_train, y_test, xgb_train_preds, xgb_test_preds)
# Out:
# Model: XGBoost
# ------------------------------------------------------------
# test accuracy: 0.8320846711856345
# train accuracy: 0.8877675840978593
# ------------------------------------------------------------
#
# test report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      4872
#            1       0.83      0.75      0.79      3537
#
#     accuracy                           0.83      8409
#    macro avg       0.83      0.82      0.82      8409
# weighted avg       0.83      0.83      0.83      8409
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91     11266
#            1       0.90      0.83      0.86      8354
#
#     accuracy                           0.89     19620
#    macro avg       0.89      0.88      0.88     19620
# weighted avg       0.89      0.89      0.89     19620
#
# ...

# %%
roc(X_test,y_test,xgb_test_preds,xgb_pipeline)

# %%
top_feat(xgb_pipeline)
# Out:
# Explanation(estimator="XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,\n              colsample_bynode=1, colsample_bytree=1.0, eta=0.3, gamma=0,\n              gpu_id=-1, importance_type='gain', interaction_constraints='',\n              learning_rate=0.300000012, max_delta_step=0, max_depth=10,\n              min_child_weight=6, missing=nan, monotone_constraints='()',\n              n_estimators=100, n_jobs=0, num_parallel_tree=1,\n              objective='binary:logistic', random_state=42, reg_alpha=0,\n              reg_lambda=1, scale_pos_weight=1, subsample=0.8,\n              tree_method='exact', validate_parameters=1, verbosity=None)", description='\nXGBoost feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='quantity_dry', weight=0.17029358, std=None, value=None), FeatureWeight(
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier


forest_params = {'model__n_estimators' : [500,1000], 'model__criterion' : ['gini','entropy'], 
                        'model__max_depth': [10], 'model__min_samples_split' : [10],'model__max_features':['auto'],
                                 'model__min_samples_leaf' : [5]}

# %%
rfc = { 'model': RandomForestClassifier(random_state=42), 'params': forest_params }

rfc_test_preds, rfc_train_preds,rfc_pipeline = fit_predict(rfc, X_train, X_test, y_train, y_test)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:  2.0min finished
# Best parameter (CV score=0.764):
# {'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'auto', 'model__min_samples_leaf': 5, 'model__min_samples_split': 10, 'model__n_estimators': 500}

# %%
metrics('RandomForest', y_train, y_test, rfc_train_preds, rfc_test_preds)
# Out:
# Model: RandomForest
# ------------------------------------------------------------
# test accuracy: 0.7588298251872994
# train accuracy: 0.7672782874617737
# ------------------------------------------------------------
#
# test report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.94      0.82      4872
#            1       0.87      0.50      0.64      3537
#
#     accuracy                           0.76      8409
#    macro avg       0.80      0.72      0.73      8409
# weighted avg       0.78      0.76      0.74      8409
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82     11266
#            1       0.87      0.53      0.66      8354
#
#     accuracy                           0.77     19620
#    macro avg       0.80      0.74      0.74     19620
# ...

# %%
roc(X_test,y_test,rfc_test_preds,rfc_pipeline)

# %%
top_feat(rfc_pipeline)
# Out:
# Explanation(estimator="RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,\n                       criterion='gini', max_depth=10, max_features='auto',\n                       max_leaf_nodes=None, max_samples=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=5, min_samples_split=10,\n                       min_weight_fraction_leaf=0.0, n_estimators=500,\n                       n_jobs=None, oob_score=False, random_state=42, verbose=0,\n                       warm_start=False)", description='\nRandom forest feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='quantity_dry', weight=0.11902620759759946, std=0.18660877708252238, value=None), FeatureWeight(feature='age_of_well', weight=0.07466148203999723, std=0.1282015531
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# __The purpose of this project:__
#
# To try different classification models in order to allow the user (e.g. the Tanzanian Ministry of Water) to attempt to identify which pumps are in need of repairs (whether functional or not) based on data that includes multiple features, such as: the quality of water provided by the pump, quantity of water, funding source, whether public meetings take place to discuss the status of these pumps, etc... This would allow the user (such as the Tanzanian Ministry of Water) to make predictions on which water delivery systems are experiencing mechanical issues and proactively attempt to repair them, thus maintaining the availability of potable water.

# %% [markdown]
# Our dataset contains information about 59,400 Tanzanian water pumps. There are 40 attributes (some of which are purely administrative) that could potentially be predictor variables. These attributes are either administrative variables, categorical variables, or non-categorical numerical variables. The response variable is: are the wells fully functional (negative class), or are they in need of repairs (positive class).

# %% [markdown]
# The following attributes were used in our models: GPS Height, Installer, Basin, Region, District Code, Ward, Public Meeting, Scheme Management, Permit, Extraction Type Group, Management, Management Group, Payment, Water Quality, Quality Group, Quantity, Source, Source Class, Waterpoint Type, Population Bin, and Age of Well. Therefore, 21 attributes, of the 40 available, were used in the models.

# %% [markdown]
# The following models were used: Linear SVC, XGBoost, and Random Forest. The model that worked best was XGBoost, and it provided the following metrics:

# %%
metrics('XGBoost', y_train, y_test, xgb_train_preds, xgb_test_preds)
# Out:
# Model: XGBoost
# ------------------------------------------------------------
# test accuracy: 0.8320846711856345
# train accuracy: 0.8877675840978593
# ------------------------------------------------------------
#
# test report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      4872
#            1       0.83      0.75      0.79      3537
#
#     accuracy                           0.83      8409
#    macro avg       0.83      0.82      0.82      8409
# weighted avg       0.83      0.83      0.83      8409
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91     11266
#            1       0.90      0.83      0.86      8354
#
#     accuracy                           0.89     19620
#    macro avg       0.89      0.88      0.88     19620
# weighted avg       0.89      0.89      0.89     19620
#
# ...

# %%
roc(X_test,y_test,xgb_test_preds,xgb_pipeline)

# %% [markdown]
# The following parameters grid was used with XGBoost:
#
# xgb_param = {
#
#     'model__colsample_bytree': [1.0],
#
#     'model__eta': [.3, .2, .1, .05, .01, .005],
#
#     'model__max_depth': [10],
#
#     'model__min_child_weight': [6],
#
#     'model__subsample': [0.8]
# }
#
#
# Significance of parameters:
# - colsample_bytree: Denotes the fraction of columns to be randomely sampled for each tree.
# - eta: Makes the model more robust by shrinking the weights on each step.
# - max depth: Defines the maximum depth. Higher depth will allow the model to learn relations very specific to a particular sample.
# - min_child_weight: Defines the minimum sum of weights of all observations - required in a child. Used to control over-fitting. Higher values prevent a model from learning relations which might be highly specific to the particular sample selected for a tree.
# - subsample: Denotes the fraction of observations to be randomly sampled for each tree. Lower values make the algorithm more conservative and prevent overfitting but values that are too small might lead to under-fitting.

# %%
# parameters that provided the best model

xgb_pipeline.best_params_
# Out:
# {'model__colsample_bytree': 1.0,
#  'model__eta': 0.3,
#  'model__max_depth': 10,
#  'model__min_child_weight': 6,
#  'model__subsample': 0.8}
